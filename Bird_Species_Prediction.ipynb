# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
#  11.10.2022.ParthKalkar.WeeklyReport.docx
# 'academic transcript.pdf'
#  archive.zip
#  card.jpg
# 'Colab Notebooks'
# 'Copy of 11.11.2022.ParthKalkar.WeeklyReport.docx'
# 'Copy of ParthKalkar_CV.docx'
# 'Copy of ParthKalkar_CV.docx.pdf'
# 'Copy of PIRATE KING Resume - Dark.gdoc'
# 'Copy of PIRATE KING Resume - White.gdoc'
# 'Copy of Reference letter_Germany - Elvina.gdoc'
#  CoverLetter.gdoc
# 'Cover Letter Template + Resources.gdoc'
#  Data
# 'Data Science Practice.gdoc'
#  final_SOP.docx
#  Google-Docs-Invoice-Template-SC-2-G.docx
# 'HABRN - Communication Assignment.gdoc'
# 'HABRN - Emotion Assignment.gdoc'
# 'HABRN - Movement and Training Assignment.gdoc'
# 'How to get started with Drive.pdf'
# 'IMDB Dataset.csv'
#  IMG_20220829_144022_434.jpg
# 'Interview preparation.gdoc'
#  Letter.gdoc
# 'Masters University.gdoc'
# 'Material for SLR.gdoc'
# 'Migration Certificate .pdf'
#  model
# 'MS Admission Enquiry Letter.gdoc'
# 'Online Food Industry Market research.gdoc'
# 'ParthKalkar_CV (1).pdf'
#  ParthKalkar_CV.docx
#  ParthKalkar_CV.pdf
# 'Parth_Kalkar_R&D_Resume.gdoc'
#  passport
# 'Peer Review SLR.gdoc'
# 'PMLDL-D1.1 Report.gdoc'
# 'PMLDL-D1.2 Report.gdoc'
# 'PMLDL-D1.3 Report.gdoc'
# 'Project proposal.gdoc'
# 'Resume Template + Resources.gdoc'
#  SBES_LeavingCertificate.pdf
#  SOP.gdoc
# 'Structured Abstract.gdoc'
#  Thesis.gdoc
#  Vaccine_certificate_ENG.pdf
#  Vaccine_certificate_RU.pdf

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Data/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Data/Bird Speciees Dataset/BARN OWL"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
# display random birds
plt.figure(figsize=(12,12))
random_path = ["/content/drive/MyDrive/Data/Bird Speciees Dataset/AMERICAN GOLDFINCH",
               "/content/drive/MyDrive/Data/Bird Speciees Dataset/BARN OWL",
               "/content/drive/MyDrive/Data/Bird Speciees Dataset/CARMINE BEE-EATER",
               "/content/drive/MyDrive/Data/Bird Speciees Dataset/DOWNY WOODPECKER",
               "/content/drive/MyDrive/Data/Bird Speciees Dataset/EMPEROR PENGUIN",
               "/content/drive/MyDrive/Data/Bird Speciees Dataset/FLAMINGO"]
path =  random.choice(random_path)
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Setting path and creating empty list
dir = "/content/drive/MyDrive/Data/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Check for class imbalance.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 10s 193ms/step - loss: 1.7783 - accuracy: 0.1969 - val_loss: 1.7215 - val_accuracy: 0.3077
# Epoch 2/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.6733 - accuracy: 0.3803 - val_loss: 1.6367 - val_accuracy: 0.2769
# Epoch 3/50
# 5/5 [==============================] - 0s 79ms/step - loss: 1.5709 - accuracy: 0.3494 - val_loss: 1.5459 - val_accuracy: 0.3615
# Epoch 4/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.4606 - accuracy: 0.4421 - val_loss: 1.4693 - val_accuracy: 0.3769
# Epoch 5/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.4310 - accuracy: 0.4421 - val_loss: 1.3549 - val_accuracy: 0.4462
# Epoch 6/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.3771 - accuracy: 0.4768 - val_loss: 1.3155 - val_accuracy: 0.4846
# Epoch 7/50
# 5/5 [==============================] - 0s 84ms/step - loss: 1.2790 - accuracy: 0.5309 - val_loss: 1.2696 - val_accuracy: 0.5000
# Epoch 8/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.2328 - accuracy: 0.5116 - val_loss: 1.1872 - val_accuracy: 0.5077
# Epoch 9/50
# 5/5 [==============================] - 0s 82ms/step - loss: 1.1600 - accuracy: 0.5830 - val_loss: 1.1604 - val_accuracy: 0.5385
# Epoch 10/50
# 5/5 [==============================] - 0s 92ms/step - loss: 1.1124 - accuracy: 0.6178 - val_loss: 1.0442 - val_accuracy: 0.5923
# Epoch 11/50
# 5/5 [==============================] - 1s 99ms/step - loss: 1.0416 - accuracy: 0.6448 - val_loss: 1.0553 - val_accuracy: 0.5538
# Epoch 12/50
# 5/5 [==============================] - 0s 100ms/step - loss: 0.9911 - accuracy: 0.6622 - val_loss: 0.9569 - val_accuracy: 0.5769
# Epoch 13/50
# 5/5 [==============================] - 1s 120ms/step - loss: 0.9409 - accuracy: 0.6622 - val_loss: 0.9200 - val_accuracy: 0.6000
# Epoch 14/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.8573 - accuracy: 0.6757 - val_loss: 0.8390 - val_accuracy: 0.6385
# Epoch 15/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8373 - accuracy: 0.7046 - val_loss: 1.0640 - val_accuracy: 0.6000
# Epoch 16/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8940 - accuracy: 0.6834 - val_loss: 0.8329 - val_accuracy: 0.6923
# Epoch 17/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.8384 - accuracy: 0.6815 - val_loss: 1.0687 - val_accuracy: 0.5769
# Epoch 18/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.0036 - accuracy: 0.6602 - val_loss: 0.8311 - val_accuracy: 0.6385
# Epoch 19/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.7533 - accuracy: 0.7336 - val_loss: 0.7921 - val_accuracy: 0.6538
# Epoch 20/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6997 - accuracy: 0.7490 - val_loss: 0.7515 - val_accuracy: 0.6846
# Epoch 21/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6439 - accuracy: 0.7992 - val_loss: 0.7415 - val_accuracy: 0.6692
# Epoch 22/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6024 - accuracy: 0.7934 - val_loss: 0.6804 - val_accuracy: 0.7615
# Epoch 23/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.5909 - accuracy: 0.7838 - val_loss: 0.6433 - val_accuracy: 0.7615
# Epoch 24/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.5380 - accuracy: 0.8147 - val_loss: 0.6618 - val_accuracy: 0.7154
# Epoch 25/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.5053 - accuracy: 0.8436 - val_loss: 0.6237 - val_accuracy: 0.7846
# Epoch 26/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.4756 - accuracy: 0.8494 - val_loss: 0.6352 - val_accuracy: 0.7154
# Epoch 27/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.4788 - accuracy: 0.8417 - val_loss: 0.6442 - val_accuracy: 0.7154
# Epoch 28/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.4375 - accuracy: 0.8629 - val_loss: 0.5851 - val_accuracy: 0.7923
# Epoch 29/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.4032 - accuracy: 0.8900 - val_loss: 0.5967 - val_accuracy: 0.7538
# Epoch 30/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.3803 - accuracy: 0.8726 - val_loss: 0.5705 - val_accuracy: 0.7923
# Epoch 31/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.3664 - accuracy: 0.8822 - val_loss: 0.5875 - val_accuracy: 0.7615
# Epoch 32/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.3470 - accuracy: 0.8784 - val_loss: 0.5526 - val_accuracy: 0.7769
# Epoch 33/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.3658 - accuracy: 0.8764 - val_loss: 0.6254 - val_accuracy: 0.7615
# Epoch 34/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.3433 - accuracy: 0.8822 - val_loss: 0.5716 - val_accuracy: 0.7538
# Epoch 35/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.3509 - accuracy: 0.8726 - val_loss: 0.5640 - val_accuracy: 0.7769
# Epoch 36/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2927 - accuracy: 0.9112 - val_loss: 0.6294 - val_accuracy: 0.7385
# Epoch 37/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.3424 - accuracy: 0.8958 - val_loss: 0.5444 - val_accuracy: 0.7769
# Epoch 38/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.3015 - accuracy: 0.9054 - val_loss: 0.5719 - val_accuracy: 0.7615
# Epoch 39/50
# 5/5 [==============================] - 0s 84ms/step - loss: 0.3472 - accuracy: 0.8822 - val_loss: 0.5476 - val_accuracy: 0.8000
# Epoch 40/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2625 - accuracy: 0.9363 - val_loss: 0.5726 - val_accuracy: 0.7538
# Epoch 41/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2850 - accuracy: 0.9208 - val_loss: 0.5460 - val_accuracy: 0.8154
# Epoch 42/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2484 - accuracy: 0.9266 - val_loss: 0.6048 - val_accuracy: 0.7615
# Epoch 43/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2353 - accuracy: 0.9344 - val_loss: 0.5781 - val_accuracy: 0.8077
# Epoch 44/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2456 - accuracy: 0.9286 - val_loss: 0.5669 - val_accuracy: 0.7846
# Epoch 45/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.2198 - accuracy: 0.9324 - val_loss: 0.5692 - val_accuracy: 0.7923
# Epoch 46/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2486 - accuracy: 0.9151 - val_loss: 0.6125 - val_accuracy: 0.7615
# Epoch 47/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2162 - accuracy: 0.9402 - val_loss: 0.5783 - val_accuracy: 0.8077
# Epoch 48/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1731 - accuracy: 0.9614 - val_loss: 0.5557 - val_accuracy: 0.7769
# Epoch 49/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1849 - accuracy: 0.9498 - val_loss: 0.6064 - val_accuracy: 0.7846
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1621 - accuracy: 0.9556 - val_loss: 0.5629 - val_accuracy: 0.7923

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
# Saving model
model.save("/content/drive/MyDrive/Data/bird_species.h5")

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 29ms/step - loss: 0.8106 - accuracy: 0.7669
# Test Accuracy: 76.68711543083191

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 12ms/step

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Plotting image to compare
img = array_to_img(x_test[6])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F6751A7BE50>

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[6])])
print("Predicted : ",labels[np.argmax(y_pred[6])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  FLAMINGO
# Predicted :  FLAMINGO

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.

# %% [markdown]
# # Scope:

# %% [markdown]
# This project can be used for educational purposes to get a better understanding of how to create network architecture for a CNN model. You can further hyper parameter tune this model to reach a higher accuracy. It can be used by bird sanctuaries to identify different types of birds.
